# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 (necesario en algunos entornos)

# Definición de la función por partes
def fxy(x, y):
    r2 = (x - 1)**2 + (y + 2)**2
    return np.where(r2 <= 1, 1 - r2, np.exp(-r2))

# Malla de puntos
x = np.linspace(-2, 4, 400)
y = np.linspace(-5, 1, 400)
X, Y = np.meshgrid(x, y)
Z = fxy(X, Y)

# --- Superficie 3D ---
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, linewidth=0, antialiased=True, alpha=0.95)

ax.set_title(r"$f(x,y)=\begin{cases}1-((x-1)^2+(y+2)^2), & ((x-1)^2+(y+2)^2)\le 1\\ e^{-((x-1)^2+(y+2)^2)}, & ((x-1)^2+(y+2)^2)>1\end{cases}$")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x,y)")

# Proyección de contornos en el plano z=min(Z)
zmin = Z.min()
ax.contour(X, Y, Z, zdir='z', offset=zmin, levels=20)

plt.tight_layout()
plt.show()

# --- Mapa de calor 2D con círculo de frontera ---
plt.figure(figsize=(6, 5))
plt.imshow(Z, extent=[x.min(), x.max(), y.min(), y.max()],
           origin='lower', aspect='auto')
plt.colorbar(label='f(x,y)')
plt.title("Mapa de calor de f(x,y)")

# Círculo frontera: (x-1)^2 + (y+2)^2 = 1
theta = np.linspace(0, 2*np.pi, 400)
xc = 1 + np.cos(theta)
yc = -2 + np.sin(theta)
plt.plot(xc, yc, 'k--', linewidth=1.5, label='frontera r^2=1')
plt.xlabel("x"); plt.ylabel("y")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 30
#      27 zmin = Z.min()
#      28 ax.contour(X, Y, Z, zdir='z', offset=zmin, levels=20)
# ---> 30 plt.tight_layout()
#      31 plt.show()
#      33 # --- Mapa de calor 2D con círculo de frontera ---
#
# File c:\Users\samue\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2844, in tight_layout(pad, h_pad, w_pad, rect)
#    2836 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2837 def tight_layout(
#    2838     *,
#    (...)   2842     rect: tuple[float, float, float, float] | None = None,
#    2843 ) -> None:
# -> 2844     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File c:\Users\samue\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
# ...
